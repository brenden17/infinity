# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import e

x = np.linspace(-10, 10, 100)
y = np.exp(x)

#plt.plot(x, y)

f = lambda x: np.exp(-x**2/2)/np.sqrt(2*np.pi) + sin(x)/2

plt.plot(x, f(x))

# %%
plt.plot(x, y)
